# %% [markdown]
# ## Análise da literatura:
#
# Os genes encolhidos para a realização do trabalho foram: TGFB1, IL-10, IL-13 e STAT6
#
# Para entender melhor o papel biológico dos genes, foi realizado a análise da literatura existente em artigos científicos e especificamente em artigos disponíveis na PubMed que é uma base de dados da National Library of Medicine dos Estados Unidos, especializada em literatura biomédica.
#
# - Para a análise exigida foi formulado pelo grupo duas funções 'buscar_artigos' e 'dados_artigos', com o uso dos módulos Bio e doi.

# %%
# Necessário o uso do módulo Entrez do Bio para a busca dos termos de interesse
from Bio import Entrez
Entrez.email = 'A.N.Other@example.com'

#A função definida faz a busca do termo de interesse na base de dados PubMed e retorna o número de documentos encontrados e os ids dos documentos selecionados. 
def buscar_artigos(term : str, max_artigos : int):
    """ Input: o termo de interesse e o números de artigos máximo para selecionar da busca realizada
        Output: o número de artigos encontrados e os ids dos max_artigos
    """
    links = Entrez.esearch(db="pubmed", retmax = max_artigos, term=term)	
    l = Entrez.read(links)
    ids = l.get("IdList")
    return {"Número de artigos encontrados": l.get("Count"), "Ids dos artigos definidos": ids}

# %%
import doi

# %%
# Determinação de uma função que retorna o título do artigo, data de publicação, nome dos autores e o URL do documento
from Bio import Medline
def dados_artigos(ids_art):
    """
    O input é o Id do artigo de interesse e retorna o título do artigo, data de publicação, nome dos autores e o URL do documento
    """
    handle = Entrez.efetch(db="pubmed", id=ids_art, rettype="medline", retmode="text")
    lista = Medline.parse(handle)

    for r in lista:
        print("------------------")
        print("Título do Artigo:", r.get("TI"))
        print("Data de publicação:", r.get("DP"))
        print("Autores:", r.get("AU"))
        d = r.get("LID")
        print(d)

# %% [markdown]
# #### *Resultados da busca literária para os genes de interesse:*
# - Genes de busca: IL13, STAT6, IL10 e TGFB1.
# - A busca foi realizada para 20 artigos para cada gene de interesse.
#
# <span style='color: red;'>Os resultados alteram a partir da data de pesquisa.</span>

# %%
#Termos de pesquisa:
terms = ["IL13", "STAT6", "IL10", "TGFB1"]

# %%
# Resultados das pesquisa de no máximo 20 artigos para cada termo:
term1 = buscar_artigos(terms[0], 20)
term2 = buscar_artigos(terms[1], 20)
term3 = buscar_artigos(terms[2], 20)
term4 = buscar_artigos(terms[3], 20)

print("***Pesquisa para o gene {}***".format(terms[0]), term1, "\n","***Pesquisa para o gene {}***".format(terms[1]),term2, "\n","***Pesquisa para o gene {}***".format(terms[2]),term3, "\n","***Pesquisa para o gene {}***".format(terms[3]),term4)
# Out:
# ***Pesquisa para o gene IL13*** {'Número de artigos encontrados': '17316', 'Ids dos artigos definidos': ['38205486', '38203533', '38203432', '38201655', '38197326', '38193513', '38191383', '38187864', '38187281', '38186188', '38186139', '38185848', '38181714', '38179747', '38179046', '38179045', '38178909', '38178133', '38178132', '38176525']}
#  ***Pesquisa para o gene STAT6*** {'Número de artigos encontrados': '4318', 'Ids dos artigos definidos': ['38205453', '38201452', '38188367', '38173372', '38172698', '38167296', '38162655', '38144091', '38136901', '38136399', '38134634', '38133747', '38114221', '38112587', '38104875', '38098120', '38095318', '38087324', '38082280', '38079450']}
#  ***Pesquisa para o gene IL10*** {'Número de artigos encontrados': '82843', 'Ids dos artigos definidos': ['38205677', '38205666', '38205394', '38204622', '38203690', '38203402', '38203391', '38203327', '38203178', '38201981', '38201878', '38201870', '38201264', '38201073', '38199503', '38199260', '38198999', '38198970', '38198914', '38198893']}
#  ***Pesquisa para o gene TGFB1*** {'Número de artigos encontrados': '9564', 'Ids dos artigos definidos': ['38193973', '38190933', '38171389', '38169377', '38160764', '38149583', '38144939', '38134933', '38132522', '38111465', '38107385', '38094507', '38092632', '38074633', '38070752', '38070245', '38068980', '38065378', '38059389', '38054018']}

# %%
# Artigos para o gene: IL13
t1 = dados_artigos(term1.get("Ids dos artigos definidos"))
t1
# Out:
# ------------------
# Título do Artigo: Revolutionizing Dupilumab Treatment in Refractory Eosinophilic Cellulitis: A Case Report and Comprehensive Literature Review.
# Data de publicação: 2023 Dec
# Autores: ['Shah D']
# 10.7759/cureus.50333 [doi]
# ------------------
# Título do Artigo: New Perspectives in the Management of Chronic Hand Eczema: Lessons from Pathogenesis.
# Data de publicação: 2023 Dec 27
# Autores: ['Tancredi V', 'Buononato D', 'Caccavale S', 'Di Brizzi EV', 'Di Caprio R', 'Argenziano G', 'Balato A']
# 362 [pii] 10.3390/ijms25010362 [doi]
# ------------------
# Título do Artigo: How Do Classical Subtypes Correspond to Endotypes in Atopic Dermatitis?
# Data de publicação: 2023 Dec 23
# Autores: ['Suzuki T', 'Kondo S', 'Ogura Y', 'Otsuka M', 'Tokura Y']
# 265 [pii] 10.3390/ijms25010265 [doi]
# ------------------
# Título do Artigo: Expression of Interleukin-13 Receptor Alpha 2 in Brainstem Gliomas.
# Data de publicação: 2024 Jan 3
# Autores: ['Li X', 'Xiao X', 'Wang Y', 'Gu G', 'Li T', 'Wang Y', 'Li C', 'Zhang P', 'Ji N', 'Zhang Y', 'Zhang L']
# 228 [pii] 10.3390/cancers16010228 [doi]
# ------------------
# Título do Artigo: Safety of dupilumab in T2 airways conditions: focus on eosinophilia across trials and real-life evidence.
# Data de publicação: 2024 Jan 10
# Autores: ['Caminati M', 'Micheletto C', 'Norelli F', 'Olivieri B', 'Ottaviano G', 'Padoan R', 'Piacentini G', 'Schiappoli M', 'Senna G', 'Menzella F']
# 10.1080/14712598.2024.2304556 [doi]
# ------------------
# Título do Artigo: Relevant Research of Inflammatory Cytokines Spectrum in Peripheral Blood of Sudden Hearing Loss.
# Data de publicação: 2024 Jan 9
# Autores: ['Tan X', 'Pan J', 'Cai J', 'Jiang S', 'Shu F', 'Xu M', 'Peng H', 'Tang J', 'Zhang H']
# 10.1002/lary.31276 [doi]
# ------------------
# Título do Artigo: Postmenopausal women with HIV have increased tooth loss.
# Data de publicação: 2024 Jan 8
# Autores: ['Wadhwa S', 'Finn TR', 'Kister K', 'Matsumura S', 'Levit M', 'Cantos A', 'Shah J', 'Bohn B', 'Lalla E', 'Grbic JT', 'Demmer RT', 'Yin MT']
# 10.1186/s12903-023-03744-y [doi] 52
# ------------------
# Título do Artigo: Sialic acid-modified der p 2 allergen exerts immunomodulatory effects on human PBMCs.
# Data de publicação: 2024 Feb
# Autores: ['Keumatio Doungtsop BC', 'Nardini E', 'Kalay H', 'Versteeg SA', 'Lubbers J', 'van Barneveld G', 'Li ERJ', 'van Vliet SJ', 'van Ree R', 'de Jong EC', 'van Kooyk Y']
# 10.1016/j.jacig.2023.100193 [doi] 100193
# ------------------
# Título do Artigo: TRPM2 exacerbates airway inflammation by regulating oxidized-CaMKⅡ in allergic asthma.
# Data de publicação: 2024 Jan 15
# Autores: ['Liu X', 'Zhao L', 'Wang R', 'Tang Z']
# 10.1016/j.heliyon.2023.e23634 [doi] e23634
# ------------------
# Título do Artigo: Resveratrol modulates the Nrf2/NF-kappaB pathway and inhibits TSLP-mediated atopic march.
# Data de publicação: 2024
# Autores: ['He Q', 'Liu W', 'Chen Z', 'Wei G', 'Jiang J', 'Zhang L', 'Zhou L']
# 10.15586/aei.v52i1.963 [doi]
# ------------------
# Título do Artigo: [The similar characteristics of IgG4-related disease and allergic diseases].
# Data de publicação: 2023 Dec 6
# Autores: ['Bian SN', 'Guan K']
# 10.3760/cma.j.cn112150-20230712-00535 [doi]
# ------------------
# Título do Artigo: Perivascular space burden and cerebrospinal fluid biomarkers in U.S. Veterans with blast-related mild traumatic brain injury.
# Data de publicação: 2024 Jan 7
# Autores: ['Yamamoto E', 'Koike S', 'Luther M', 'Dennis L', 'Lim MM', 'Raskind M', 'Pagulayan K', 'Iliff J', 'Peskind E', 'Piantino J']
# 10.1089/neu.2023.0505 [doi]
# ------------------
# Título do Artigo: Cardioprotection by the adiponectin receptor agonist ALY688 in a preclinical mouse model of heart failure with reduced ejection fraction (HFrEF).
# Data de publicação: 2024 Jan 3
# Autores: ['Cho S', 'Dadson K', 'Sung HK', 'Ayansola O', 'Mirzaesmaeili A', 'Noskovicova N', 'Zhao Y', 'Cheung K', 'Radisic M', 'Hinz B', 'Sater AAA', 'Hsu HH', 'Lopaschuk GD', 'Sweeney G']
# S0753-3322(23)01917-0 [pii] 10.1016/j.biopha.2023.116119 [doi]
# ------------------
# Título do Artigo: DPP4 Regulates the Th17/IL-17 Axis and Accelerates Epithelial Mesenchymal Transition to Promote Ovalbumin-Induced Asthma in Female C57BL/6J Mice.
# Data de publicação: 2023 Dec 26
# Autores: ['Li L', 'Ling F', 'Li R', 'Jiang Y', 'Long H', 'Xiao B', 'Wu J', 'Long Z', 'Ma L']
# 10.31083/j.fbl2812342 [doi]
# ------------------
# Título do Artigo: The impact of prior SARS-CoV-2 infection on host inflammatory cytokine profiles in patients with TB or other respiratory diseases.
# Data de publicação: 2023
# Autores: ['Cottam A', 'Manneh IL', 'Gindeh A', 'Sillah AK', 'Cham O', 'Mendy J', 'Barry A', 'Coker EG', 'Daffeh GK', 'Badjie S', 'Barry S', 'Owolabi O', 'Winter J', 'Walzl G', 'Sutherland JS']
# 10.3389/fimmu.2023.1292486 [doi] 1292486
# ------------------
# Título do Artigo: ILC2-mediated immune crosstalk in chronic (vascular) inflammation.
# Data de publicação: 2023
# Autores: ['Kral M', 'van der Vorst EPC', 'Surnov A', 'Weber C', 'Doring Y']
# 10.3389/fimmu.2023.1326440 [doi] 1326440
# ------------------
# Título do Artigo: Emerging diagnostic markers and therapeutic targets in post-stroke hemorrhagic transformation and brain edema.
# Data de publicação: 2023
# Autores: ['Yao Y', 'Liu F', 'Gu Z', 'Wang J', 'Xu L', 'Yu Y', 'Cai J', 'Ren R']
# 10.3389/fnmol.2023.1286351 [doi] 1286351
# ------------------
# Título do Artigo: CD147 induces asthmatic airway remodeling and activation of circulating fibrocytes in a mouse model of asthma.
# Data de publicação: 2024 Jan 4
# Autores: ['Li Z', 'Cheng T', 'Guo Y', 'Gao R', 'Ma X', 'Mao X', 'Han X']
# 10.1186/s12931-023-02646-5 [doi] 6
# ------------------
# Título do Artigo: VEGF and EGFR signaling pathways are involved in the baicalein attenuation of OVA-induced airway inflammation and airway remodeling in mice.
# Data de publicação: 2024 Jan 4
# Autores: ['Peng W', 'Xia Q', 'Zhang Y', 'Cao D', 'Zheng X']
# 10.1186/s12931-023-02637-6 [doi] 10
# ------------------
# Título do Artigo: Temporal cytokine storm dynamics in dengue infection predicts severity.
# Data de publicação: 2024 Jan 5
# Autores: ['Bhatt P', 'Varma M', 'Sood V', 'Ambikan A', 'Jayaram A', 'Babu N', 'Gupta S', 'Mukhopadhyay C', 'Neogi U']
# S0168-1702(23)00268-X [pii] 10.1016/j.virusres.2023.199306 [doi]

# %%
# Artigos para o gene: STAT6
t2 = dados_artigos(term2.get("Ids dos artigos definidos"))
t2
# Out:
# ------------------
# Título do Artigo: Adrenal Solitary Fibrous Tumor: A Case Report.
# Data de publicação: 2023 Dec
# Autores: ['Casademunt-Gras E', 'Salinas I', 'Moreno Santabarbara P', 'Tapia Melendo G', 'Reverter JL']
# 10.7759/cureus.50300 [doi]
# ------------------
# Título do Artigo: JAK1 Is a Novel Target of Tumor- and Invasion-Suppressive microRNA 494-5p in Colorectal Cancer.
# Data de publicação: 2023 Dec 20
# Autores: ['Patil N', 'Abdelrahim OG', 'Leupold JH', 'Allgayer H']
# 24 [pii] 10.3390/cancers16010024 [doi]
# ------------------
# Título do Artigo: Targeting STAT6 to mitigate sepsis-induced muscle atrophy and weakness: Modulation of mitochondrial dysfunction, ferroptosis, and CHI3L1-Mediated satellite cell loss.
# Data de publicação: 2024 Mar
# Autores: ['Sheng Z', 'Yu Z', 'Wang M', 'Zhou R', 'Chen S', 'Yu X', 'Li F']
# 10.1016/j.bbrep.2023.101608 [doi] 101608
# ------------------
# Título do Artigo: DWN12088, A Prolyl-tRNA Synthetase Inhibitor, Alleviates Hepatic Injury in Nonalcoholic Steatohepatitis.
# Data de publicação: 2024 Jan 3
# Autores: ['Lee DK', 'Jo SH', 'Lee ES', 'Ha KB', 'Park NW', 'Kong DH', 'Park SI', 'Park JS', 'Chung CH']
# 10.4093/dmj.2022.0367 [doi]
# ------------------
# Título do Artigo: PRMT2 silencing regulates macrophage polarization through activation of STAT1 or inhibition of STAT6.
# Data de publicação: 2024 Jan 3
# Autores: ['Liu T', 'Li Y', 'Xu M', 'Huang H', 'Luo Y']
# 10.1186/s12865-023-00593-w [doi] 1
# ------------------
# Título do Artigo: Mcam inhibits macrophage-mediated development of mammary gland through non-canonical Wnt signaling.
# Data de publicação: 2024 Jan 2
# Autores: ['Yang X', 'Xu H', 'Yang X', 'Wang H', 'Zou L', 'Yang Q', 'Qi X', 'Li L', 'Duan H', 'Yan X', 'Fu NY', 'Tan J', 'Hou Z', 'Jiao B']
# 10.1038/s41467-023-44338-0 [doi] 36
# ------------------
# Título do Artigo: Thrombocyte-derived Dickkopf1 promotes macrophage polarization in the Bleomycin-induced lung injury model.
# Data de publicação: 2023
# Autores: ['Sung EA', 'Park MH', 'Song S', 'Alanya H', 'Henegariu O', 'Liu J', 'Erson-Omay EZ', 'Sime PJ', 'Chae WJ']
# 10.3389/fimmu.2023.1247330 [doi] 1247330
# ------------------
# Título do Artigo: Integrating Network Pharmacology and Experimental Validation to Elucidate the Mechanism of Jiegeng Decoction in Improving Allergic Asthma.
# Data de publicação: 2023 Dec 19
# Autores: ['Wu Z', 'Luo Z', 'Sun W', 'Shi Y', 'Ding Q']
# 10.1021/acsomega.3c06914 [doi]
# ------------------
# Título do Artigo: Effects of Dietary Limosilactobacillus fermentum and Lacticaseibacillus paracasei Supplementation on the Intestinal Stem Cell Proliferation, Immunity, and Ileal Microbiota of Broiler Chickens Challenged by Coccidia and Clostridium perfringens.
# Data de publicação: 2023 Dec 15
# Autores: ['Guo S', 'Tong W', 'Qi Y', 'Jiang M', 'Li P', 'Zhang Z', 'Hu Q', 'Song Z', 'Ding B']
# 10.3390/ani13243864 [doi] 3864
# ------------------
# Título do Artigo: Diagnostics and Treatment of Extrameningeal Solitary Fibrous Tumors.
# Data de publicação: 2023 Dec 15
# Autores: ['Janik AM', 'Terlecka A', 'Spalek MJ', 'Boye K', 'Szostakowski B', 'Chmiel P', 'Szumera-Cieckiewicz A', 'Bobak K', 'Switaj T', 'Rutkowski P', 'Czarnecka AM']
# 10.3390/cancers15245854 [doi] 5854
# ------------------
# Título do Artigo: The role of tumor-associated macrophages in lung cancer: From mechanism to small molecule therapy.
# Data de publicação: 2024 Jan
# Autores: ['Zhou Y', 'Qian M', 'Li J', 'Ruan L', 'Wang Y', 'Cai C', 'Gu S', 'Zhao X']
# S0753-3322(23)01812-7 [pii] 10.1016/j.biopha.2023.116014 [doi]
# ------------------
# Título do Artigo: IL-4Ralpha Inhibition for Severe "Eosinophilic Gastroenteritis, Allergy, and Anaphylaxis" Syndrome due to a Gain-of-Function Variant in STAT6.
# Data de publicação: 2023 Dec 22
# Autores: ['Faguer S', 'Delabesse E', 'Paul C', 'Pasquet M']
# 10.1007/s10875-023-01639-9 [doi]
# ------------------
# Título do Artigo: [Tongxie Yaofang regulates tumor-associated macrophage polarization in colorectal cancer under chronic stress].
# Data de publicação: 2023 Nov
# Autores: ['Yang Y', 'Hu YE', 'Huang YQ', 'Jiang YF', 'Fu X', 'You FM']
# 10.19540/j.cnki.cjcmm.20230811.703 [doi]
# ------------------
# Título do Artigo: The protective effects of Phoenixin-20 in tumor necrosis factor alpha (TNF-alpha)-induced cell senescence of rheumatoid arthritis fibroblast-like synoviocytes (FLS).
# Data de publicação: 2023 Nov 28
# Autores: ['Yan J', 'Yao L', 'Tan Y', 'Wang Y']
# 10.18632/aging.205024 [doi]
# ------------------
# Título do Artigo: Uncovering the pharmacological mechanism of Shou Tai Wan on recurrent spontaneous abortion: A integrated pharmacology strategy-based research.
# Data de publicação: 2023 Dec 15
# Autores: ['Yang K', 'Zeng L', 'Li Y', 'Wu L', 'Xiang W', 'Wu X', 'Wang G', 'Bao T', 'Huang S', 'Yu R', 'Zhang G', 'Liu H']
# S0378-8741(23)01459-9 [pii] 10.1016/j.jep.2023.117589 [doi]
# ------------------
# Título do Artigo: The secretome of Staphylococcus aureus strains with opposite within-herd epidemiological behavior affects bovine mononuclear cell response.
# Data de publicação: 2023 Dec 14
# Autores: ['Di Mauro S', 'Filipe J', 'Facchin A', 'Roveri L', 'Addis MF', 'Monistero V', 'Piccinini R', 'Sala G', 'Pravettoni D', 'Zamboni C', 'Ceciliani F', 'Lecchi C']
# 10.1186/s13567-023-01247-w [doi] 120
# ------------------
# Título do Artigo: Evaluation of transcription factors and cytokine expressions of T-cell subsets in CD19 deficiency and their possible relationship with autoimmune disease.
# Data de publicação: 2024 Feb
# Autores: ['Kuccukturk S', 'Karaselek MA', 'Duran T', 'Reisli I']
# 10.1111/apm.13363 [doi]
# ------------------
# Título do Artigo: Interleukin-30 subverts prostate cancer-endothelium crosstalk by fostering angiogenesis and activating immunoregulatory and oncogenic signaling pathways.
# Data de publicação: 2023 Dec 12
# Autores: ['Ciummo SL', 'Sorrentino C', 'Fieni C', 'Di Carlo E']
# 10.1186/s13046-023-02902-y [doi] 336
# ------------------
# Título do Artigo: Medrysone promotes corneal injury repair by promoting M2-like polarization of macrophages.
# Data de publicação: 2023 Dec 11
# Autores: ['Zhu Y', 'Jin X', 'Fu N', 'Li J']
# 10.1186/s12886-023-03234-3 [doi] 503
# ------------------
# Título do Artigo: Hookworms dynamically respond to loss of Type 2 immune pressure.
# Data de publicação: 2023 Dec
# Autores: ['Ferguson AA', 'Inclan-Rico JM', 'Lu D', 'Bobardt SD', 'Hung L', 'Gouil Q', 'Baker L', 'Ritchie ME', 'Jex AR', 'Schwarz EM', 'Rossi HL', 'Nair MG', 'Dillman AR', 'Herbert DR']
# 10.1371/journal.ppat.1011797 [doi] e1011797

# %%
# Artigos para o gene: IL10
t3 = dados_artigos(term3.get("Ids dos artigos definidos"))
t3
# Out:
# ------------------
# Título do Artigo: Grape seed proanthocyanidin extract alleviates inflammation in experimental colitis mice by inhibiting NF-kappaB signaling pathway.
# Data de publicação: 2024 Jan 11
# Autores: ['Chu L', 'Zhang S', 'Wu W', 'Gong Y', 'Chen Z', 'Wen Y', 'Wang Y', 'Wang L']
# 10.1002/tox.24129 [doi]
# ------------------
# Título do Artigo: A CONSORT-guided, randomized controlled clinical trial of nebulized administration of dexamethasone and saline on lower airway cytokine mRNA expression in horses with moderate asthma.
# Data de publicação: 2024 Jan 11
# Autores: ['Bond S', 'Leguillette R']
# 10.1111/jvim.16983 [doi]
# ------------------
# Título do Artigo: Huang Gan Formula Alleviates Systemic Inflammation and Uremia in Adenine-Induced Chronic Kidney Disease Rats May Associate with Modification of Gut Microbiota and Colonic Microenvironment.
# Data de publicação: 2024
# Autores: ['Zhao J', 'Zhao C', 'Xun T', 'Wang X', 'Wei S', 'Ye C', 'Zhang M', 'Guo D', 'Yang X']
# 10.2147/DDDT.S421446 [doi]
# ------------------
# Título do Artigo: Ischemic myocardial inflammatory signaling in starvation versus hypoxia-derived extracellular vesicles: A comparative analysis.
# Data de publicação: 2023 Dec
# Autores: ['Sabra M', 'Sabe SA', 'Harris DD', 'Xu CM', 'Broadwin M', 'Bellam KG', 'Banerjee D', 'Abid MR', 'Sellke FW']
# 10.1016/j.xjon.2023.10.004 [doi]
# ------------------
# Título do Artigo: Study of the Effect of Wild-Type and Transiently Expressing CXCR4 and IL-10 Mesenchymal Stromal Cells in a Mouse Model of Peritonitis.
# Data de publicação: 2023 Dec 30
# Autores: ['Garcia Gomez-Heras S', 'Garcia-Arranz M', 'Vega-Clemente L', 'Olivera-Salazar R', 'Velez Pinto JF', 'Fernandez-Garcia M', 'Guadalajara H', 'Yanez R', 'Garcia-Olmo D']
# 520 [pii] 10.3390/ijms25010520 [doi]
# ------------------
# Título do Artigo: The Combination of Bioavailable Concentrations of Curcumin and Resveratrol Shapes Immune Responses While Retaining the Ability to Reduce Cancer Cell Survival.
# Data de publicação: 2023 Dec 23
# Autores: ['Focaccetti C', 'Palumbo C', 'Benvenuto M', 'Carrano R', 'Melaiu O', 'Nardozi D', 'Angiolini V', 'Lucarini V', 'Kerpi B', 'Masuelli L', 'Cifaldi L', 'Bei R']
# 232 [pii] 10.3390/ijms25010232 [doi]
# ------------------
# Título do Artigo: Downregulation of Salt-Inducible Kinase 3 Enhances CCL24 Activation in the Placental Environment with Preeclampsia.
# Data de publicação: 2023 Dec 22
# Autores: ['Tsai HF', 'Tseng CF', 'Liang YL', 'Wu PY', 'Huang LY', 'Lin YH', 'Lin LH', 'Lin CN', 'Hsu KF']
# 222 [pii] 10.3390/ijms25010222 [doi]
# ------------------
# Título do Artigo: Accumulation of Inflammatory Mediators in the Normal Pericardial Fluid.
# Data de publicação: 2023 Dec 21
# Autores: ['El-Diasty MM', 'Rodriguez J', 'Perez L', 'Eiras S', 'Fernandez AL']
# 157 [pii] 10.3390/ijms25010157 [doi]
# ------------------
# Título do Artigo: Biological Effects of "Inflammageing" on Human Oral Cells: Insights into a Potential Confounder of Age-Related Diseases.
# Data de publicação: 2023 Dec 19
# Autores: ['Alexakou E', 'Bakopoulou A', 'Apatzidou DA', 'Kritis A', 'Malousi A', 'Anastassiadou V']
# 5 [pii] 10.3390/ijms25010005 [doi]
# ------------------
# Título do Artigo: Effect of the Combination of Clostridium butyricum and Mycelium of Phellinus igniarius on Intestinal Microbiota and Serum Metabolites in DSS-Induced Colitis.
# Data de publicação: 2024 Jan 2
# Autores: ['Zhao R', 'Zhang Q', 'Huang T', 'Tian Y', 'Guan G', 'Lin Y']
# 153 [pii] 10.3390/nu16010153 [doi]
# ------------------
# Título do Artigo: Age-Dependent Effect of Calcitriol on Mouse Regulatory T and B Lymphocytes.
# Data de publicação: 2023 Dec 22
# Autores: ['Sniezewska A', 'Anisiewicz A', 'Gdesz-Birula K', 'Wietrzyk J', 'Filip-Psurska B']
# 49 [pii] 10.3390/nu16010049 [doi]
# ------------------
# Título do Artigo: Effect of Fish Oil Parenteral Emulsion Supplementation on Inflammatory Parameters after Esophagectomy.
# Data de publicação: 2023 Dec 21
# Autores: ['Suarez-Lledo Grande A', 'Llop Talaveron JM', 'Leiva Badosa E', 'Farran Teixido L', 'Miro Martin M', 'Bas Minguet J', 'Navarro Velazquez S', 'Creus Costas G', 'Virgili Casas N', 'Fernandez Alvarez M', 'Badia Tahull MB']
# 40 [pii] 10.3390/nu16010040 [doi]
# ------------------
# Título do Artigo: Fecal Supernatants from Patients with Crohn's Disease Induce Inflammatory Alterations in M2 Macrophages and Fibroblasts.
# Data de publicação: 2023 Dec 27
# Autores: ['Gorreja F', 'Bendix M', 'Rush STA', 'Maasfeh L', 'Savolainen O', 'Dige A', 'Agnholt J', 'Ohman L', 'Magnusson MK']
# 60 [pii] 10.3390/cells13010060 [doi]
# ------------------
# Título do Artigo: Isolation and Characterization of n-3 Polyunsaturated Fatty Acids in Enteromorpha prolifera Lipids and Their Preventive Effects on Ulcerative Colitis in C57BL/6J Mice.
# Data de publicação: 2023 Dec 21
# Autores: ['Wen H', 'Leong PM', 'Wang X', 'Li D']
# 46 [pii] 10.3390/foods13010046 [doi]
# ------------------
# Título do Artigo: Could we use PD-1 and PD-L1 expression on lymphocytes and monocytes as predictive markers for prognosis of acute biliary pancreatitis?
# Data de publicação: 2024 Jan 8
# Autores: ['Idiz UO', 'Aru B', 'Kaya C', 'Peker KD', 'Tatar C', 'Guler M', 'Tunay A', 'Demirel GY', 'Gurol AO']
# S0165-2478(24)00002-6 [pii] 10.1016/j.imlet.2024.106836 [doi]
# ------------------
# Título do Artigo: Sialylated IVIg promotes clinical improvements in a rabbit dry eye model by regulating inflammatory cytokines.
# Data de publicação: 2024 Jan 8
# Autores: ['Choi H', 'Lee HE', 'Lee SV', 'Joo JS', 'Baek H', 'Kim S', 'Park M', 'Yang SW', 'Hwang HS', 'Lee SW', 'Kim JY', 'Kang YS']
# S0014-4835(24)00003-4 [pii] 10.1016/j.exer.2024.109782 [doi]
# ------------------
# Título do Artigo: Functionally multifaceted alginate/curdlan/agarose-based bilayer fibro-porous dressings for addressing full-thickness diabetic wounds.
# Data de publicação: 2024 Jan 3
# Autores: ['Latiyan S', 'Kumar TSS', 'Doble M']
# S2772-9508(23)00480-6 [pii] 10.1016/j.bioadv.2023.213757 [doi]
# ------------------
# Título do Artigo: Myeloid-specific deletion of group VIA calcium-independent phospholipase A2 induces pro-inflammatory LPS response predominantly in male mice via MIP-1alpha activation.
# Data de publicação: 2024 Jan 9
# Autores: ['Klement L', 'Jansakun C', 'Yan B', 'Staffer S', 'Tuma-Kellner S', 'Altamura S', 'Muckenthaler M', 'Merle U', 'Chamulitrat W']
# S0925-4439(24)00001-2 [pii] 10.1016/j.bbadis.2024.167016 [doi]
# ------------------
# Título do Artigo: Effects of exposing Japanese quail eggs to a low dose of gamma radiation and in ovo feeding by two sources of trace elements on embryonic development activities.
# Data de publicação: 2023 Dec 9
# Autores: ['Hatab MH', 'Chen W', 'Abouelezz K', 'Elaroussi M', 'Badran A', 'Zoheir K', 'El-Komy E', 'Li S', 'Elokil A']
# S0032-5791(23)00884-2 [pii] 10.1016/j.psj.2023.103364 [doi]
# ------------------
# Título do Artigo: Predicting gene-level sensitivity to JAK-STAT signaling perturbation using a mechanistic-to-machine learning framework.
# Data de publicação: 2024 Jan 3
# Autores: ['Cheemalavagu N', 'Shoger KE', 'Cao YM', 'Michalides BA', 'Botta SA', 'Faeder JR', 'Gottschalk RA']
# S2405-4712(23)00360-5 [pii] 10.1016/j.cels.2023.12.006 [doi]

# %%
# Artigos para o gene: TGFB1
t4 = dados_artigos(term4.get("Ids dos artigos definidos"))
t4
# Out:
# ------------------
# Título do Artigo: The role of basic leucine zipper transcription factor E4BP4 in cancer: a review and update.
# Data de publicação: 2024 Jan 9
# Autores: ['Wang L', 'Li P', 'Zhang X', 'Gu Z', 'Pan X', 'Wu Y', 'Li H']
# 10.1007/s11033-023-09079-9 [doi]
# ------------------
# Título do Artigo: Distant neuroinflammation acutely induced by focal brain injury and its control by endocannabinoid system.
# Data de publicação: 2024 Jan 6
# Autores: ['Karan AA', 'Spivak YS', 'Suleymanova EM', 'Gerasimov KA', 'Bolshakov AP', 'Vinogradova LV']
# S0014-4886(24)00005-0 [pii] 10.1016/j.expneurol.2024.114679 [doi]
# ------------------
# Título do Artigo: The roles and mechanisms of TGFB1 in acute myeloid leukemia chemoresistance.
# Data de publicação: 2024 Jan 1
# Autores: ['Liang X', 'Zhou J', 'Li C', 'Wang H', 'Wan Y', 'Ling C', 'Pu L', 'Zhang W', 'Fan M', 'Hong J', 'Zhai Z']
# S0898-6568(23)00442-4 [pii] 10.1016/j.cellsig.2023.111027 [doi]
# ------------------
# Título do Artigo: Identification and validation of iron metabolism genes in osteoporosis.
# Data de publicação: 2024 Jan 2
# Autores: ['Li Z', 'Xu J', 'Shi S', 'Weng Y', 'Guo B', 'Che L', 'Sun J']
# 10.1186/s12920-023-01779-2 [doi] 5
# ------------------
# Título do Artigo: Genomic Risk Factors for Urethral Stricture: A Systematic Review and Gene Network Analysis.
# Data de publicação: 2023 Dec 30
# Autores: ['Isali I', 'Wong TR', 'Wu CW', 'Scarberry K', 'Gupta S', 'Erickson BA', 'Breyer BN']
# S0090-4295(23)01118-4 [pii] 10.1016/j.urology.2023.12.014 [doi]
# ------------------
# Título do Artigo: Establishment and characterization of amitrole-induced mouse thyroid adenomatous nodule-derived cell lines.
# Data de publicação: 2023 Dec 27
# Autores: ['Shirai YT', 'Hoshi N', 'Ward JM', 'Liu H', 'Cachau RE', 'Lee MP', 'Kimura S']
# 10.1089/thy.2023.0341 [doi]
# ------------------
# Título do Artigo: Effect of Low-Level Laser Irradiation (810 nm) on the Proliferation and Differentiation of Osteoblast-Like Cells Cultured on SLA Titanium Discs Exposed to a Peri-implantitis Environment.
# Data de publicação: 2023
# Autores: ['Zampa EP', 'Kyriakidou K', 'Papaparaskevas J', 'Pepelassi E', 'Karoussis IK']
# 10.34172/jlms.2023.57 [doi] e57
# ------------------
# Título do Artigo: Time-resolved single-cell transcriptomics defines immune trajectories in glioblastoma.
# Data de publicação: 2024 Jan 4
# Autores: ['Kirschenbaum D', 'Xie K', 'Ingelfinger F', 'Katzenelenbogen Y', 'Abadie K', 'Look T', 'Sheban F', 'Phan TS', 'Li B', 'Zwicky P', 'Yofe I', 'David E', 'Mazuz K', 'Hou J', 'Chen Y', 'Shaim H', 'Shanley M', 'Becker S', 'Qian J', 'Colonna M', 'Ginhoux F', 'Rezvani K', 'Theis FJ', 'Yosef N', 'Weiss T', 'Weiner A', 'Amit I']
# S0092-8674(23)01317-X [pii] 10.1016/j.cell.2023.11.032 [doi]
# ------------------
# Título do Artigo: Anti-Fibronectin Aptamer Modifies Blood Clot Pattern and Stimulates Osteogenesis: An Ex Vivo Study.
# Data de publicação: 2023 Dec 1
# Autores: ['da Costa NMM', 'Parisi L', 'Ghezzi B', 'Elviri L', 'de Souza SLS', 'Novaes AB Junior', 'de Oliveira PT', 'Macaluso GM', 'Palioto DB']
# 10.3390/biomimetics8080582 [doi] 582
# ------------------
# Título do Artigo: Mapping knowledge structure and themes trends of cancer-associated fibroblasts: a text-mining study.
# Data de publicação: 2023
# Autores: ['Cheng K', 'Li W', 'Wu H', 'Li C']
# 10.3389/fmolb.2023.1302016 [doi] 1302016
# ------------------
# Título do Artigo: Bioinformatics Prediction and Experimental Validation of the Role of Macrophage Polarization and Ferroptosis in Gestational Diabetes Mellitus.
# Data de publicação: 2023
# Autores: ['Chen C', 'Yang Z', 'Qiu Z']
# 10.2147/JIR.S440826 [doi]
# ------------------
# Título do Artigo: Optimizing Platelet and Leucocyte-Rich Plasma as Biomaterials for Ophthalmic Applications: Impact of Centrifugation Speed.
# Data de publicação: 2023
# Autores: ['Castillo-Macias A', 'Zavala J', 'Ortega-Lara W', 'Garcia-Herrera SM', 'Valdez-Garcia JE']
# 10.2147/OPTH.S444840 [doi]
# ------------------
# Título do Artigo: The elevation of plasma galectin-9 levels in patients with psoriasis and its associations with inflammatory and immune checkpoint molecules in skin tissues.
# Data de publicação: 2023 Dec 12
# Autores: ['Chagan-Yasutan H', 'He N', 'Arlud S', 'Fang J', 'Hattori T']
# S0198-8859(23)00376-2 [pii] 10.1016/j.humimm.2023.110741 [doi]
# ------------------
# Título do Artigo: Pre-treatment inflamed tumor immune microenvironment is associated with FOLFIRINOX response in pancreatic cancer.
# Data de publicação: 2023
# Autores: ['Gao Z', 'Kang SW', 'Erstad D', 'Azar J', 'Van Buren G', 'Fisher W', 'Sun Z', 'Rubinstein MP', 'Lee HS', 'Camp ER']
# 10.3389/fonc.2023.1274783 [doi] 1274783
# ------------------
# Título do Artigo: Mechanisms related to carbon nanotubes genotoxicity in human cell lines of respiratory origin.
# Data de publicação: 2023 Dec 7
# Autores: ['Fatkhutdinova LM', 'Gabidinova GF', 'Daminova AG', 'Dimiev AM', 'Khamidullin TL', 'Valeeva EV', 'Cokou AEE', 'Validov SZ', 'Timerbulatova GA']
# S0041-008X(23)00423-4 [pii] 10.1016/j.taap.2023.116784 [doi]
# ------------------
# Título do Artigo: Formononetin ameliorates isoproterenol induced cardiac fibrosis through improving mitochondrial dysfunction.
# Data de publicação: 2024 Jan
# Autores: ['Qian L', 'Xu H', 'Yuan R', 'Yun W', 'Ma Y']
# S0753-3322(23)01798-5 [pii] 10.1016/j.biopha.2023.116000 [doi]
# ------------------
# Título do Artigo: Transcriptomics of MASLD Pathobiology in African American Patients in the Washington DC Area (dagger).
# Data de publicação: 2023 Nov 23
# Autores: ['Mondal T', 'Smith CI', 'Loffredo CA', 'Quartey R', 'Moses G', 'Howell CD', 'Korba B', 'Kwabi-Addo B', 'Nunlee-Bland G', 'R Rucker L', 'Johnson J', 'Ghosh S']
# 10.3390/ijms242316654 [doi] 16654
# ------------------
# Título do Artigo: Effect of nonsteroidal anti-inflammatory drugs on pelvic floor muscle regeneration in a preclinical birth injury rat model.
# Data de publicação: 2023 Dec 6
# Autores: ['Kobayashi AJ', 'Sesillo FB', 'Do E', 'Alperin M']
# S0002-9378(23)02118-X [pii] 10.1016/j.ajog.2023.12.001 [doi]
# ------------------
# Título do Artigo: The mechanisms underlying alcohol-induced decreased splenic size: A network meta-analysis study.
# Data de publicação: 2024 Jan
# Autores: ['Liu X', 'Bishir M', 'Hodgkinson C', 'Goldman D', 'Chang SL']
# 10.1111/acer.15234 [doi]
# ------------------
# Título do Artigo: Identification of cytokine-induced cell communications by pan-cancer meta-analysis.
# Data de publicação: 2023
# Autores: ['Liu Y', 'Zhao M', 'Qu H']
# 10.7717/peerj.16221 [doi] e16221

# %% [markdown]
# ## Download dos genes de interesse
# - Download dos genes e criação de documentos com as informações obtidas.
# - Os accesion dos genes:
#   - TGFB1 : NG_013364
#   - IL13  : NG_012090
#   - IL10  : NG_012088
#   - STAT6 : NG_021272

# %%
# Definição de uma função para o download do gene
from Bio import Entrez
from Bio import SeqIO
Entrez.email = 'A.N.Other@example.com'
def download_gene(id_gene : str, name_gene : str):
    handle = Entrez.efetch(db="nucleotide", rettype="gb", retmode="text",id= id_gene)
    for seq_record in SeqIO.parse(handle, "gb"):
        SeqIO.write(seq_record, "{}.gb".format(name_gene), "gb")
        print(f"Download do GENBANK do gene {id_gene} completado.")

# %%
# Download dos gones de interesse:
download_gene("NG_013364", "TGFB1")
download_gene("NG_012090", "IL13")
download_gene("NG_012088", "IL10")
download_gene("NG_021272", "STAT6")
# Out:
# Download do GENBANK do gene NG_013364 completado.
# Download do GENBANK do gene NG_012090 completado.
# Download do GENBANK do gene NG_012088 completado.
# Download do GENBANK do gene NG_021272 completado.

# %%
#Função para fazer download do ficheiro FASTA com as sequências dos genes
from Bio import Entrez
from Bio import SeqIO
Entrez.email = 'A.N.Other@example.com'
def download_fasta(gene_id, filename):
    try:
        handle = Entrez.efetch(db="nucleotide", id=gene_id, rettype="fasta", retmode="text")
        with open(filename, "w") as out_file:
            out_file.write(handle.read())
        handle.close()
        print(f"Download do FASTA do gene {gene_id} completado.")
    except Exception as e:
        print(f"Erro: {e}")

# %%
# Download das sequências de interesse
download_fasta('NG_012090', 'IL13.fasta')
download_fasta('NG_012088', 'IL10.fasta')
download_fasta('NG_021272', 'STAT6.fasta')
download_fasta('NG_013364', 'TGFB1.fasta')
# Out:
# Download do FASTA do gene NG_012090 completado.
# Download do FASTA do gene NG_012088 completado.
# Download do FASTA do gene NG_021272 completado.
# Download do FASTA do gene NG_013364 completado.
